# %% [markdown]
# ### Topological Data Analysis - CG point cloud/Ripser

# %%
from ripser import ripser
from persim import plot_diagrams
import matplotlib.pyplot as plt
import numpy as np

import ipynb
from ipynb.fs.full.AFML_CG_xyz import read_XYZ
from ipynb.fs.full.AFML_CG_xyz import cut_out
from ipynb.fs.full.AFML_CG_xyz import plot_facet_2d
from ipynb.fs.full.AFML_CG_xyz import plot_facet_3d

# %%
data = np.load('PAR_cut_xyz_test.npy')
plot_facet_2d(data)

# %%
dgms = ripser(data)['dgms']
plot_diagrams(dgms, show=True)
