# %% [markdown]
# #### AFML mat-eig Terrace Outline Extraction

# %%
from AFML_functions import *

# %%
facet = read_XYZ('/Users/user/Documents/PhD/AFML/CG_PAR_H2O_3mil/20231121_103655/XYZ_files/PAR_H2O_20-1_1_ovito_CGvisualiser_unscaled.xyz')
terrace = remove_z_levels(facet, [1.0, 2.0, 4.0])
terrace_rotate = rotate_point_cloud(terrace, (2, 0, -1))

# %%
## NEED to consider structure fo 20-1 facet to see if points ... or /\/\
plot_CG_3d(terrace)
plot_CG_3d(terrace_rotate)
